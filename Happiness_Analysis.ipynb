# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import linregress

# %%
file_path = 'world_happiness.csv'
happiness_df = pd.read_csv(file_path)
happiness_df.rename(columns = {'Country name': 'Country'}, inplace=True)

happiness_df.head()
# Out:
#    RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0     1      Finland            7.821         7.886        7.756
# 1     2      Denmark            7.636         7.710        7.563
# 2     3      Iceland            7.557         7.651        7.464
# 3     4  Switzerland            7.512         7.586        7.437
# 4     5  Netherlands            7.415         7.471        7.359
#
#    Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                       2.518                         1.892
# 1                       2.226                         1.953
# 2                       2.320                         1.936
# 3                       2.153                         2.026
# 4                       2.137                         1.945
#
#    Explained by: Social support  Explained by: Healthy life expectancy  \
# 0                         1.258                                  0.775
# ...

# %%
#replacing '*' in country names
happiness_df["Country"] = happiness_df["Country"].str.replace( "*" , "" )
happiness_df
# Out:
# C:\Users\John\AppData\Local\Temp\ipykernel_5084\3506616449.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   happiness_df["Country"] = happiness_df["Country"].str.replace( "*" , "" )
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 142   143       Rwanda            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# ...

# %%
#removing row 147
happiness_df = happiness_df.drop([146])
happiness_df
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 141   142     Botswana            3.471         3.667        3.275
# 142   143       Rwanda            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                         2.518                         1.892
# ...

# %%
#check for duplicate countries
happiness_df['Country'].value_counts()
# Out:
# Finland        1
# Iran           1
# Bangladesh     1
# Laos           1
# Algeria        1
#               ..
# Kuwait         1
# Hungary        1
# Mauritius      1
# Uzbekistan     1
# Afghanistan    1
# Name: Country, Length: 146, dtype: int64

# %%
#there are not any NAN
happiness_df = happiness_df.dropna()
happiness_df
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 141   142     Botswana            3.471         3.667        3.275
# 142   143       Rwanda            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  Explained by: GDP per capita  \
# 0                         2.518                         1.892
# ...

# %%
#renaming columns
happiness_df = happiness_df.rename(columns = {'Explained by: GDP per capita': 'GDP per capita',
                                             'Explained by: Social support': 'social support',
                                             'Explained by: Healthy life expectancy': 'healthy life expectancy',
                                             'Explained by: Freedom to make life choices': 'freedom to make life choices',
                                             'Explained by: Generosity': 'generosity',
                                             'Explained by: Perceptions of corruption': 'perceptions of corruption'})
happiness_df
# Out:
#      RANK      Country  Happiness score  Whisker-high  Whisker-low  \
# 0       1      Finland            7.821         7.886        7.756
# 1       2      Denmark            7.636         7.710        7.563
# 2       3      Iceland            7.557         7.651        7.464
# 3       4  Switzerland            7.512         7.586        7.437
# 4       5  Netherlands            7.415         7.471        7.359
# ..    ...          ...              ...           ...          ...
# 141   142     Botswana            3.471         3.667        3.275
# 142   143       Rwanda            3.268         3.462        3.074
# 143   144     Zimbabwe            2.995         3.110        2.880
# 144   145      Lebanon            2.955         3.049        2.862
# 145   146  Afghanistan            2.404         2.469        2.339
#
#      Dystopia (1.83) + residual  GDP per capita  social support  \
# 0                         2.518           1.892           1.258
# ...

# %%
#corr table for reference
corr = happiness_df.corr()
corr = corr.style.background_gradient(cmap='coolwarm')
corr

# %%
#export to csv
happiness_df.to_csv('cleaned_data.csv')

# %%
#import clean csv
csv_path = "cleaned_data.csv"
happiness_df = pd.read_csv(csv_path, encoding="UTF-8")
happiness_df

# %%
# What happens to happiness when a country has high levels of social support? - Amanda
x_values = happiness_df['social support']
y_values = happiness_df['Happiness score']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,45),fontsize=15,color="red")
plt.xlabel('Social Support')
plt.ylabel('Happiness')
plt.title("Social Support & Happiness 2022")

# Save the figure
#plt.savefig("MaxTempsNorth.png")

plt.show()

# %%
# What happens to happiness when a country has high levels of freedom? - Joey
x_values = happiness_df['freedom to make life choices']
y_values = happiness_df['Happiness score']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,45),fontsize=15,color="red")
plt.xlabel('Life Choice Freedom')
plt.ylabel('Happiness')
plt.title("Freedom & Happiness 2022")

# Save the figure
#plt.savefig("MaxTempsNorth.png")

plt.show()

# %%
# What happens to happiness when a country has a high GDP? - Nathan
x_values = happiness_df['GDP per capita']
y_values = happiness_df['Happiness score']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,45),fontsize=15,color="red")
plt.xlabel('GDP per Capita')
plt.ylabel('Happiness')
plt.title("GDP & Happiness 2022")

# Save the figure
#plt.savefig("MaxTempsNorth.png")

plt.show()

# %%
# What happens to happiness when a country has higher life expectancy? - John

# %%
happiness_df["healthy life expectancy"].unique()

# %%
x_values = happiness_df['healthy life expectancy']
y_values = happiness_df['Happiness score']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,45),fontsize=15,color="red")
plt.xlabel('Life Expectancy')
plt.ylabel('Happiness')
plt.title("Life Expectancy & Happiness 2022")

# Save the figure
#plt.savefig("MaxTempsNorth.png")

plt.show()

# %%
# ------------------------------

# %%
x_values = happiness_df['social support']
y_values = happiness_df['freedom to make life choices']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(5,45),fontsize=15,color="red")
plt.xlabel('Social Services')
plt.ylabel('Freedom')
plt.title("Social Services & Freedom")

# Save the figure
#plt.savefig("MaxTempsNorth.png")

plt.show()
